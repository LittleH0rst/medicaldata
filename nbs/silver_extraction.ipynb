# %%
import os
import polars as pl

# %%
# Set Polars to show full DataFrame output (no truncation)
pl.Config.set_tbl_formatting("ASCII_FULL")   # or "UTF8_FULL" if you prefer UTF8 borders
pl.Config.set_tbl_rows(1000)      # Increase max rows (default is 10)
pl.Config.set_tbl_cols(50)        # Increase max columns (default is 10)

# Now your print(group_df) will show full content


# read data from bronze table into a DataFrame
file_path = "data/bronze_df.parquet"

# Load the Parquet file into a Polars DataFrame
df = pl.read_parquet(file_path)

columns = df.columns
print(columns)
# Out:
# ['subject_id', 'hadm_id', 'stay_id', 'itemid', 'value', 'valuenum', 'valueuom', 'label', 'abbreviation', 'unitname']

# %%
# overview of the data
all_code_groups = {
    "Gender Codes": {
        226228: "Gender"
    },
    "Age Codes": {
        226984: "Apache IV Age"
    },
    "Confusion / Mental Instability": {
        228395: "Orientation to Place",
        228394: "Orientation to Person",
        229381: "Orientation",
        223898: "Orientation",
        228396: "Orientation to Time",
        226104: "Level of Consciousness",
        229382: "Orientation Score",
        228688: "Delirium",
        2930: "Delirium due to conditions classified elsewhere",
        2903: "Senile dementia with delirium",
        2931: "Subacute delirium",
        2982: "Reactive confusion",
        29281: "Drug-induced delirium",
        29011: "Presenile dementia with delirium",
        78097: "Altered mental status",
        29041: "Vascular dementia, with delirium",
        "F05": "Delirium due to known physiological condition"
    },
    "Respiratory Rate": {
        230040: "Paradoxical breathing"
    },
    "Blood Pressure": {
        225309: "ART BP Systolic",
        227243: "Manual Blood Pressure Systolic Right",
        220179: "Non Invasive Blood Pressure Systolic",
        220050: "Arterial Blood Pressure Systolic",
        224167: "Manual Blood Pressure Systolic Left"
    },
    "Temperature": {
        224027: "Skin Temperature",
        223761: "Temperature Fahrenheit",
        223762: "Temperature Celsius",
        226329: "Blood Temperature CCO (C)",
        50825: "Temperature Blood Blood Gas"
    },
    "Pulse Rates": {
        229770: "Resting Pulse Rate (COWS)",
        223942: "Graft/Flap Pulse",
        223936: "Radial Pulse R",
        223948: "Radial Pulse L",
        223941: "Popliteal Pulse R",
        223946: "Popliteal Pulse L",
        223949: "Ulnar Pulse L",
        223945: "Femoral Pulse L",
        223939: "Brachial Pulse R",
        223944: "Brachial Pulse L",
        223940: "Femoral Pulse R",
        223938: "Ulnar Pulse R"
    },
    "BUN": {
        225624: "BUN",
        51842: "Bun"
    },
    "pH": {
        50820: "pH",
        223830: "PH (Arterial)"
    },
    "Sodium": {
        220645: "Sodium (serum)",
        226534: "Sodium (whole blood)",
        228389: "Sodium (serum) (soft)",
        228390: "Sodium (whole blood) (soft)",
        50983: "Sodium",
        52623: "Sodium"
    },
    "Glucose": {
        50809: "Glucose",
        50931: "Glucose",
        52569: "Glucose",
        226537: "Glucose (whole blood)",
        225664: "Glucose finger stick (range 70-100)",
        220621: "Glucose (serum)",
        228388: "Glucose (whole blood) (soft)"
    },
    "Hematocrit": {
        52028: "Hematocrit Blood",
        51638: "Hematocrit Blood",
        51639: "Hematocrit Blood",
        51221: "Hematocrit Blood",
        226540: "Hematocrit (whole blood - calc)",
        220545: "Hematocrit (serum)"
    },
    "Oxygen Saturation": {
        220227: "Arterial O2 Saturation",
        220277: "O2 saturation pulseoxymetry",
        223835: "Inspired O2 Fraction",
        50817: "Oxygen Saturation"
    },
    "Pleural Effusion": {
        51181: "Malignant pleural effusion",
        5119: "Unspecified pleural effusion",
        "J910": "Malignant pleural effusion",
        "J918": "Pleural effusion in other conditions classified elsewhere",
        "J91": "Pleural effusion in conditions classified elsewhere"
    }
}

final_data = {}
missing_in_group = {}

for group_name, codes in all_code_groups.items():
    group_data = []
    print(f"\nProcessing {group_name}:")

    for code, description in codes.items():
        # Determine type of code and filter accordingly
        if isinstance(code, int):
            filtered_df = df.filter(pl.col("itemid") == code)
        else:
            # code is string, so cast itemid to string for comparison
            filtered_df = df.filter(pl.col("itemid").cast(pl.Utf8) == code)

        # Check if filtered_df is empty
        if filtered_df.is_empty():
            print(f"No data found for {description} (code {code}). Skipping.")
            missing_in_group[code] = description
            continue
        
        # Inspect unique units
        unique_units = filtered_df.select(pl.col("valueuom").unique())
        unique_units_list = unique_units["valueuom"].to_list()

        # Calculate range of numerical values if column exists
        if "valuenum" in filtered_df.columns and not filtered_df["valuenum"].is_empty():
            value_stats = filtered_df.select([
                pl.col("valuenum").min().alias("min_value"),
                pl.col("valuenum").max().alias("max_value")
            ])
            min_value = value_stats["min_value"][0]
            max_value = value_stats["max_value"][0]
            print(f"Range of numerical values for {description} (code {code}): {min_value} to {max_value}")
        else:
            print(f"No numerical values found for {description} (code {code}).")

        # Print unique units
        print(f"Unique units for {description} (code {code}): {unique_units_list}")

        # Append filtered data
        group_data.append(filtered_df)

    # Combine the group's filtered data into a single DataFrame if any
    final_data[group_name] = pl.concat(group_data) if group_data else None

print(missing_in_group)

# Print final DataFrames for each group
#for group_name, group_df in final_data.items():
#    print(f"\nFinal DataFrame for {group_name}:")
#    if group_df is not None:
#        print(group_df)
#    else:
#        print("No data found.")
# Out:
# Processing Gender Codes:
# No data found for Gender (code 226228). Skipping.
#
# Processing Age Codes:
# No data found for Apache IV Age (code 226984). Skipping.
#
# Processing Confusion / Mental Instability:
# Range of numerical values for Orientation to Place (code 228395): 0.0 to 2.0
# Unique units for Orientation to Place (code 228395): [None]
# Range of numerical values for Orientation to Person (code 228394): 0.0 to 2.0
# Unique units for Orientation to Person (code 228394): [None]
# Range of numerical values for Orientation (code 229381): 1.0 to 1.0
# Unique units for Orientation (code 229381): [None]
# No data found for Orientation (code 223898). Skipping.
# Range of numerical values for Orientation to Time (code 228396): 0.0 to 3.0
# Unique units for Orientation to Time (code 228396): [None]
# No data found for Level of Consciousness (code 226104). Skipping.
# No data found for Orientation Score (code 229382). Skipping.
# No data found for Delirium (code 228688). Skipping.
# No data found for Delirium due to conditions classified elsewhere (code 2930). Skipping.
# No data found for Senile dementia with delirium (code 2903). Skipping.
# No data found for Subacute delirium (code 2931). Skipping.
# No data found for Reactive confusion (code 2982). Skipping.
# No data found for Drug-induced delirium (code 29281). Skipping.
# No data found for Presenile dementia with delirium (code 29011). Skipping.
# No data found for Altered mental status (code 78097). Skipping.
# No data found for Vascular dementia, with delirium (code 29041). Skipping.
# No data found for Delirium due to known physiological condition (code F05). Skipping.
#
# Processing Respiratory Rate:
# No data found for Paradoxical breathing (code 230040). Skipping.
#
# Processing Blood Pressure:
# Range of numerical values for ART BP Systolic (code 225309): 86.0 to 143.0
# Unique units for ART BP Systolic (code 225309): ['mmHg']
# No data found for Manual Blood Pressure Systolic Right (code 227243). Skipping.
# Range of numerical values for Non Invasive Blood Pressure Systolic (code 220179): 75.0 to 215.0
# Unique units for Non Invasive Blood Pressure Systolic (code 220179): ['mmHg']
# Range of numerical values for Arterial Blood Pressure Systolic (code 220050): 62.0 to 177.0
# Unique units for Arterial Blood Pressure Systolic (code 220050): ['mmHg']
# No data found for Manual Blood Pressure Systolic Left (code 224167). Skipping.
#
# Processing Temperature:
# Range of numerical values for Skin Temperature (code 224027): None to None
# Unique units for Skin Temperature (code 224027): [None]
# Range of numerical values for Temperature Fahrenheit (code 223761): 96.4 to 103.4
# Unique units for Temperature Fahrenheit (code 223761): ['°F']
# Range of numerical values for Temperature Celsius (code 223762): 36.2 to 99.0
# Unique units for Temperature Celsius (code 223762): ['°C']
# No data found for Blood Temperature CCO (C) (code 226329). Skipping.
# No data found for Temperature Blood Blood Gas (code 50825). Skipping.
#
# Processing Pulse Rates:
# No data found for Resting Pulse Rate (COWS) (code 229770). Skipping.
# No data found for Graft/Flap Pulse (code 223942). Skipping.
# Range of numerical values for Radial Pulse R (code 223936): None to None
# Unique units for Radial Pulse R (code 223936): [None]
# Range of numerical values for Radial Pulse L (code 223948): None to None
# Unique units for Radial Pulse L (code 223948): [None]
# No data found for Popliteal Pulse R (code 223941). Skipping.
# No data found for Popliteal Pulse L (code 223946). Skipping.
# No data found for Ulnar Pulse L (code 223949). Skipping.
# No data found for Femoral Pulse L (code 223945). Skipping.
# No data found for Brachial Pulse R (code 223939). Skipping.
# No data found for Brachial Pulse L (code 223944). Skipping.
# No data found for Femoral Pulse R (code 223940). Skipping.
# Range of numerical values for Ulnar Pulse R (code 223938): None to None
# Unique units for Ulnar Pulse R (code 223938): [None]
#
# Processing BUN:
# Range of numerical values for BUN (code 225624): 7.0 to 132.0
# Unique units for BUN (code 225624): ['mg/dL']
# No data found for Bun (code 51842). Skipping.
#
# Processing pH:
# No data found for pH (code 50820). Skipping.
# Range of numerical values for PH (Arterial) (code 223830): 7.11 to 7.51
# Unique units for PH (Arterial) (code 223830): ['units']
#
# Processing Sodium:
# Range of numerical values for Sodium (serum) (code 220645): 126.0 to 154.0
# Unique units for Sodium (serum) (code 220645): ['mEq/L']
# Range of numerical values for Sodium (whole blood) (code 226534): 131.0 to 150.0
# Unique units for Sodium (whole blood) (code 226534): ['mEq/L']
# No data found for Sodium (serum) (soft) (code 228389). Skipping.
# No data found for Sodium (whole blood) (soft) (code 228390). Skipping.
# No data found for Sodium (code 50983). Skipping.
# No data found for Sodium (code 52623). Skipping.
#
# Processing Glucose:
# No data found for Glucose (code 50809). Skipping.
# No data found for Glucose (code 50931). Skipping.
# No data found for Glucose (code 52569). Skipping.
# Range of numerical values for Glucose (whole blood) (code 226537): 96.0 to 172.0
# Unique units for Glucose (whole blood) (code 226537): ['mg/dL']
# Range of numerical values for Glucose finger stick (range 70-100) (code 225664): 68.0 to 259.0
# Unique units for Glucose finger stick (range 70-100) (code 225664): [None]
# Range of numerical values for Glucose (serum) (code 220621): 34.0 to 276.0
# Unique units for Glucose (serum) (code 220621): ['mg/dL']
# No data found for Glucose (whole blood) (soft) (code 228388). Skipping.
#
# Processing Hematocrit:
# No data found for Hematocrit Blood (code 52028). Skipping.
# No data found for Hematocrit Blood (code 51638). Skipping.
# No data found for Hematocrit Blood (code 51639). Skipping.
# No data found for Hematocrit Blood (code 51221). Skipping.
# Range of numerical values for Hematocrit (whole blood - calc) (code 226540): 15.0 to 38.0
# Unique units for Hematocrit (whole blood - calc) (code 226540): ['%']
# Range of numerical values for Hematocrit (serum) (code 220545): 19.4 to 40.8
# Unique units for Hematocrit (serum) (code 220545): ['%']
#
# Processing Oxygen Saturation:
# Range of numerical values for Arterial O2 Saturation (code 220227): 95.0 to 95.0
# Unique units for Arterial O2 Saturation (code 220227): ['%']
# Range of numerical values for O2 saturation pulseoxymetry (code 220277): 50.0 to 100.0
# Unique units for O2 saturation pulseoxymetry (code 220277): ['%']
# Range of numerical values for Inspired O2 Fraction (code 223835): 21.0 to 100.0
# Unique units for Inspired O2 Fraction (code 223835): [None]
# No data found for Oxygen Saturation (code 50817). Skipping.
#
# Processing Pleural Effusion:
# No data found for Malignant pleural effusion (code 51181). Skipping.
# No data found for Unspecified pleural effusion (code 5119). Skipping.
# No data found for Malignant pleural effusion (code J910). Skipping.
# No data found for Pleural effusion in other conditions classified elsewhere (code J918). Skipping.
# No data found for Pleural effusion in conditions classified elsewhere (code J91). Skipping.
# {226228: 'Gender', 226984: 'Apache IV Age', 223898: 'Orientation', 226104: 'Level of Consciousness', 229382: 'Orientation Score', 228688: 'Delirium', 2930: 'Delirium due to conditions classified elsewhere', 2903: 'Senile dementia with delirium', 2931: 'Subacute delirium', 2982: 'Reactive confusion', 29281: 'Drug-induced delirium', 29011: 'Presenile dementia with delirium', 78097: 'Altered mental status', 29041: 'Vascular dementia, with delirium', 'F05': 'Delirium due to known physiological condition', 230040: 'Paradoxical breathing', 227243: 'Manual Blood Pressure Systolic Right', 224167: 'Manual Blood Pressure Systolic Left', 226329: 'Blood Temperature CCO (C)', 50825: 'Temperature Blood Blood Gas', 229770: 'Resting Pulse Rate (COWS)', 223942: 'Graft/Flap Pulse', 223941: 'Popliteal Pulse R', 223946: 'Popliteal Pulse L', 223949: 'Ulnar Pulse L', 223945: 'Femoral Pulse L', 223939: 'Brachial Pulse R', 223944: 'Brachial Pulse L', 223940: 'Femoral Pulse R', 51842: 'Bun', 50820: 'pH', 228389: 'Sodium (serum) (soft)', 228390: 'Sodium (whole blood) (soft)', 50983: 'Sodium', 52623: 'Sodium', 50809: 'Glucose', 50931: 'Glucose', 52569: 'Glucose', 228388: 'Glucose (whole blood) (soft)', 52028: 'Hematocrit Blood', 51638: 'Hematocrit Blood', 51639: 'Hematocrit Blood', 51221: 'Hematocrit Blood', 50817: 'Oxygen Saturation', 51181: 'Malignant pleural effusion', 5119: 'Unspecified pleural effusion', 'J910': 'Malignant pleural effusion', 'J918': 'Pleural effusion in other conditions classified elsewhere', 'J91': 'Pleural effusion in conditions classified elsewhere'}

# %%
# 50817 Oxygen Saturation → korrekt für Partial Pressure of Arterial Oxygen
# 220277 O2 saturation pulseoxymetry → ist Sauerstoffsättigung, nicht arterieller Sauerstoffpartialdruck
# Die verbleibenden Codes werden manuell überprüft, ob sie für die Kalkulation der Scores gebraucht werden, 
# zudem wird recherchiert ob die Range der Werte Sinn ergibt, oder ob in einem nächsten Schritt noch nach 
# Ausreißern gesucht werden muss

# %%
# Remove keys in data_two from all_code_groups
filtered_code_groups = {
    group: {
        key: value
        for key, value in codes.items()
        if key not in missing_in_group
    }
    for group, codes in all_code_groups.items()
}

# Remove empty groups
filtered_code_groups = {group: codes for group, codes in filtered_code_groups.items() if codes}

filtered_code_groups
# Out:
# {'Confusion / Mental Instability': {228395: 'Orientation to Place',
#   228394: 'Orientation to Person',
#   229381: 'Orientation',
#   228396: 'Orientation to Time'},
#  'Blood Pressure': {225309: 'ART BP Systolic',
#   220179: 'Non Invasive Blood Pressure Systolic',
#   220050: 'Arterial Blood Pressure Systolic'},
#  'Temperature': {224027: 'Skin Temperature',
#   223761: 'Temperature Fahrenheit',
#   223762: 'Temperature Celsius'},
#  'Pulse Rates': {223936: 'Radial Pulse R',
#   223948: 'Radial Pulse L',
#   223938: 'Ulnar Pulse R'},
#  'BUN': {225624: 'BUN'},
#  'pH': {223830: 'PH (Arterial)'},
#  'Sodium': {220645: 'Sodium (serum)', 226534: 'Sodium (whole blood)'},
#  'Glucose': {226537: 'Glucose (whole blood)',
#   225664: 'Glucose finger stick (range 70-100)',
#   220621: 'Glucose (serum)'},
#  'Hematocrit': {226540: 'Hematocrit (whole blood - calc)',
#   220545: 'Hematocrit (serum)'},
#  'Oxygen Saturation': {220227: 'Arterial O2 Saturation',
#   220277: 'O2 saturation pulseoxymetry',
#   223835: 'Inspired O2 Fraction'}}

# %%
# Manually editing the result to add the concept names and ids - checking value range in overview output
clean_codes = {

    # this part is going to be excluded, since the focus of the orientation tests is more towards determining dementia etc
    #"Confusion / Mental Instability": {
    #    228395: ("Orientation to Place", 45881443, "Confusion"),
    #    228394: ("Orientation to Person", 45881443, "Confusion"),
    #    229381: ("Orientation", 45881443, "Confusion"),
    #    228396: ("Orientation to Time", 45881443, "Confusion")
    #},

    # all correct
    "Blood Pressure": {
        225309: ("ART BP Systolic", 4152194, "Systolic blood pressure"),
        220179: ("Non Invasive Blood Pressure Systolic", 4152194, "Systolic blood pressure"),
        220050: ("Arterial Blood Pressure Systolic", 4152194, "Systolic blood pressure")
    },

    # skin temperature excluded, since no numeric results, Fahrenheit temp can be converted 
    # (is probably redundant and will therefore be filtered out)
    "Temperature": {
        # 224027: ("Skin Temperature", 36716470, "Temperature"),
        # 223761: ("Temperature Fahrenheit", 36716470, "Temperature"),
        223762: ("Temperature Celsius", 36716470, "Temperature")
    },

    # INVESTIGATE in overview only none to none value ranges, will be investigated in next step
    # after investigation - no numeric values, only if pulse is present, will be excluded
    #"Pulse Rates": {
    #    223936: ("Radial Pulse R", 4224504, "Pulse"),
    #    223948: ("Radial Pulse L", 4224504, "Pulse"),
    #    223938: ("Ulnar Pulse R", 4224504, "Pulse")
    #},

    # all correct
    "BUN": {
        225624: ("BUN", 4017361, "Blood urea nitrogen measurement")
    },

    # all correct
    "pH": {
        223830: ("PH (Arterial)", 4097822, "pH measurement, arterial")
    },

    # looking good, mEq/L instead of mmol/L, after some research, seems to be the same for Sodium
    "Sodium": {
        220645: ("Sodium (serum)", 4097430, "Sodium measurement"),
        226534: ("Sodium (whole blood)", 4097430, "Sodium measurement")
    },

    # correct, for finger there is no unit, so might exclude that
    "Glucose": {
        226537: ("Glucose (whole blood)", 4149519, "Glucose measurement"),
        #225664: ("Glucose finger stick (range 70-100)", 4149519, "Glucose measurement"),
        220621: ("Glucose (serum)", 4149519, "Glucose measurement")
    },

    # all correct
    "Hematocrit": {
        226540: ("Hematocrit (whole blood - calc)", 4151358, "Hematocrit determination"),
        220545: ("Hematocrit (serum)", 4151358, "Hematocrit determination")
    }

    # all measurements that remain are not referring to Partial pressure of arterial oxygen, but other measurements
    # of oxygen and are therfore excluded
    #"Oxygen Saturation": {
    #    220227: ("Arterial O2 Saturation", 4103460, "Partial pressure of arterial oxygen"),
    #    220277: ("O2 saturation pulseoxymetry", 4103460, "Partial pressure of arterial oxygen"),
    #    223835: ("Inspired O2 Fraction", 4103460, "Partial pressure of arterial oxygen")
    #}
}

# these are also checked later
important_labels = {
    ("gender", 4135376, "Gender"),
    ("anchor_age", 4265453, "Age"),
    ("admission_location", 45883663, "Nursing Home")
}

# %%
# get rows with labels: "gender", "anchor_age", "admission_location"

filtered_df = df.filter(pl.col("label") == "gender")

# Calculating the lexicographical range of values in the "valuenum" column
valuenum_min = filtered_df["valuenum"].min()
valuenum_max = filtered_df["valuenum"].max()

# Print results
print("Filtered DataFrame:")
print(filtered_df)

print(f"\nLexicographical Range of 'valuenum' column: (Min: {valuenum_min}, Max: {valuenum_max})")
# Out:
# Filtered DataFrame:
# shape: (7, 10)
# +----------+----------+----------+--------+-------+---------+---------+--------+---------+---------+
# | subject_ | hadm_id  | stay_id  | itemid | value | valuenu | valueuo | label  | abbrevi | unitnam |
# | id       | ---      | ---      | ---    | ---   | m       | m       | ---    | ation   | e       |
# | ---      | i64      | i64      | i64    | str   | ---     | ---     | str    | ---     | ---     |
# | i64      |          |          |        |       | f64     | str     |        | str     | str     |
# +==================================================================================================+
# | 10037975 | 27617929 | 39061571 | null   | M     | null    | null    | gender | null    | null    |
# |----------+----------+----------+--------+-------+---------+---------+--------+---------+---------|
# | 10004733 | 27411876 | 39635619 | null   | M     | null    | null    | gender | null    | null    |
# |----------+----------+----------+--------+-------+---------+---------+--------+---------+---------|
# | 10020944 | 29974575 | 30757476 | null   | M     | null    | null    | gender | null    | null    |
# |----------+----------+----------+--------+-------+---------+---------+--------+---------+---------|
# | 10027602 | 28166872 | 32391858 | null   | F     | null    | null    | gender | null    | null    |
# |----------+----------+----------+--------+-------+---------+---------+--------+---------+---------|
# | 10021487 | 28998349 | 38197705 | null   | M     | null    | null    | gender | null    | null    |
# |----------+----------+----------+--------+-------+---------+---------+--------+---------+---------|
# | 10009049 | 22995465 | 35636875 | null   | M     | null    | null    | gender | null    | null    |
# |----------+----------+----------+--------+-------+---------+---------+--------+---------+---------|
# | 10035631 | 29276678 | 30932571 | null   | M     | null    | null    | gender | null    | null    |
# +----------+----------+----------+--------+-------+---------+---------+--------+---------+---------+
#
# Lexicographical Range of 'valuenum' column: (Min: None, Max: None)

# %%
filtered_df = df.filter(pl.col("label") == "anchor_age")

# Calculating the lexicographical range of values in the "valuenum" column
valuenum_min = filtered_df["valuenum"].min()
valuenum_max = filtered_df["valuenum"].max()

# Print results
print("Filtered DataFrame:")
print(filtered_df)

print(f"\nLexicographical Range of 'valuenum' column: (Min: {valuenum_min}, Max: {valuenum_max})")
# Out:
# Filtered DataFrame:
# shape: (7, 10)
# +----------+----------+---------+--------+-------+---------+---------+---------+---------+---------+
# | subject_ | hadm_id  | stay_id | itemid | value | valuenu | valueuo | label   | abbrevi | unitnam |
# | id       | ---      | ---     | ---    | ---   | m       | m       | ---     | ation   | e       |
# | ---      | i64      | i64     | i64    | str   | ---     | ---     | str     | ---     | ---     |
# | i64      |          |         |        |       | f64     | str     |         | str     | str     |
# +==================================================================================================+
# | 10037975 | 27617929 | 3906157 | null   | 60    | null    | null    | anchor_ | null    | null    |
# |          |          | 1       |        |       |         |         | age     |         |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10004733 | 27411876 | 3963561 | null   | 51    | null    | null    | anchor_ | null    | null    |
# |          |          | 9       |        |       |         |         | age     |         |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10020944 | 29974575 | 3075747 | null   | 72    | null    | null    | anchor_ | null    | null    |
# |          |          | 6       |        |       |         |         | age     |         |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10027602 | 28166872 | 3239185 | null   | 71    | null    | null    | anchor_ | null    | null    |
# |          |          | 8       |        |       |         |         | age     |         |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | null   | 43    | null    | null    | anchor_ | null    | null    |
# |          |          | 5       |        |       |         |         | age     |         |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10009049 | 22995465 | 3563687 | null   | 56    | null    | null    | anchor_ | null    | null    |
# |          |          | 5       |        |       |         |         | age     |         |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10035631 | 29276678 | 3093257 | null   | 63    | null    | null    | anchor_ | null    | null    |
# |          |          | 1       |        |       |         |         | age     |         |         |
# +----------+----------+---------+--------+-------+---------+---------+---------+---------+---------+
#
# Lexicographical Range of 'valuenum' column: (Min: None, Max: None)

# %%
filtered_df = df.filter(pl.col("label") == "admission_location")

# Calculating the lexicographical range of values in the "valuenum" column
valuenum_min = filtered_df["valuenum"].min()
valuenum_max = filtered_df["valuenum"].max()

# Print results
print("Filtered DataFrame:")
print(filtered_df)

print(f"\nLexicographical Range of 'valuenum' column: (Min: {valuenum_min}, Max: {valuenum_max})")
# Out:
# Filtered DataFrame:
# shape: (7, 10)
# +---------+---------+---------+--------+---------+---------+---------+---------+---------+---------+
# | subject | hadm_id | stay_id | itemid | value   | valuenu | valueuo | label   | abbrevi | unitnam |
# | _id     | ---     | ---     | ---    | ---     | m       | m       | ---     | ation   | e       |
# | ---     | i64     | i64     | i64    | str     | ---     | ---     | str     | ---     | ---     |
# | i64     |         |         |        |         | f64     | str     |         | str     | str     |
# +==================================================================================================+
# | 1003797 | 2761792 | 3906157 | null   | TRANSFE | null    | null    | admissi | null    | null    |
# | 5       | 9       | 1       |        | R FROM  |         |         | on_loca |         |         |
# |         |         |         |        | HOSPITA |         |         | tion    |         |         |
# |         |         |         |        | L       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1000473 | 2741187 | 3963561 | null   | TRANSFE | null    | null    | admissi | null    | null    |
# | 3       | 6       | 9       |        | R FROM  |         |         | on_loca |         |         |
# |         |         |         |        | HOSPITA |         |         | tion    |         |         |
# |         |         |         |        | L       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1002094 | 2997457 | 3075747 | null   | EMERGEN | null    | null    | admissi | null    | null    |
# | 4       | 5       | 6       |        | CY ROOM |         |         | on_loca |         |         |
# |         |         |         |        |         |         |         | tion    |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1002760 | 2816687 | 3239185 | null   | EMERGEN | null    | null    | admissi | null    | null    |
# | 2       | 2       | 8       |        | CY ROOM |         |         | on_loca |         |         |
# |         |         |         |        |         |         |         | tion    |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1002148 | 2899834 | 3819770 | null   | EMERGEN | null    | null    | admissi | null    | null    |
# | 7       | 9       | 5       |        | CY ROOM |         |         | on_loca |         |         |
# |         |         |         |        |         |         |         | tion    |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1000904 | 2299546 | 3563687 | null   | EMERGEN | null    | null    | admissi | null    | null    |
# | 9       | 5       | 5       |        | CY ROOM |         |         | on_loca |         |         |
# |         |         |         |        |         |         |         | tion    |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003563 | 2927667 | 3093257 | null   | EMERGEN | null    | null    | admissi | null    | null    |
# | 1       | 8       | 1       |        | CY ROOM |         |         | on_loca |         |         |
# |         |         |         |        |         |         |         | tion    |         |         |
# +---------+---------+---------+--------+---------+---------+---------+---------+---------+---------+
#
# Lexicographical Range of 'valuenum' column: (Min: None, Max: None)

# %% [markdown]
# All results here look good
#
# TO check:
#
# INVESTIGATE in overview only none to none value ranges, will be investigated in next step
#
#     "Pulse Rates": {
#         223936: ("Radial Pulse R", 4224504, "Pulse"),
#         223948: ("Radial Pulse L", 4224504, "Pulse"),
#         223938: ("Ulnar Pulse R", 4224504, "Pulse")
#     },
#
# 225664: ("Glucose finger stick (range 70-100)", 4149519, "Glucose measurement"),

# %%
filtered_df = df.filter(pl.col("itemid") == 225664)

# Calculating the lexicographical range of values in the "valuenum" column
valuenum_min = filtered_df["valuenum"].min()
valuenum_max = filtered_df["valuenum"].max()

# Print results
print("Filtered DataFrame:")
print(filtered_df)

print(f"\nLexicographical Range of 'valuenum' column: (Min: {valuenum_min}, Max: {valuenum_max})")

# note - values get too high, makes sense since its measured on the finger - will still exclude it, 
# since there is no unit given, so the values cannot be interpreted
# Out:
# Filtered DataFrame:
# shape: (108, 10)
# +----------+----------+---------+--------+-------+---------+---------+---------+---------+---------+
# | subject_ | hadm_id  | stay_id | itemid | value | valuenu | valueuo | label   | abbrevi | unitnam |
# | id       | ---      | ---     | ---    | ---   | m       | m       | ---     | ation   | e       |
# | ---      | i64      | i64     | i64    | str   | ---     | ---     | str     | ---     | ---     |
# | i64      |          |         |        |       | f64     | str     |         | str     | str     |
# +==================================================================================================+
# | 10037975 | 27617929 | 3906157 | 225664 | 130   | 130.0   | null    | Glucose | Glucose | None    |
# |          |          | 1       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 165   | 165.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 131   | 131.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 136   | 136.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 153   | 153.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 172   | 172.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 116   | 116.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 149   | 149.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 134   | 134.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 195   | 195.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 113   | 113.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 132   | 132.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 151   | 151.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 133   | 133.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 143   | 143.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 131   | 131.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 144   | 144.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 133   | 133.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 141   | 141.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 147   | 147.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 150   | 150.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 124   | 124.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 135   | 135.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 144   | 144.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 147   | 147.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 146   | 146.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# |----------+----------+---------+--------+-------+---------+---------+---------+---------+---------|
# | 10021487 | 28998349 | 3819770 | 225664 | 107   | 107.0   | null    | Glucose | Glucose | None    |
# |          |          | 5       |        |       |         |         | finger  | FS      |         |
# |          |          |         |        |       |         |         | stick   | (range  |         |
# |          |          |         |        |       |         |         | (range  | 70      |         |
# |          |          |         |        |       |         |         | 70...   | -100)   |         |
# +----------+----------+---------+--------+-------+---------+---------+---------+---------+---------+
#
# Lexicographical Range of 'valuenum' column: (Min: 68.0, Max: 259.0)

# %%
filtered_df = df.filter(pl.col("itemid") == 223948) #223948, 223938 223936))

# Calculating the lexicographical range of values in the "valuenum" column
valuenum_min = filtered_df["valuenum"].min()
valuenum_max = filtered_df["valuenum"].max()

# Print results
print("Filtered DataFrame:")
print(filtered_df)

print(f"\nLexicographical Range of 'valuenum' column: (Min: {valuenum_min}, Max: {valuenum_max})")
# Out:
# Filtered DataFrame:
# shape: (158, 10)
# +---------+---------+---------+--------+---------+---------+---------+---------+---------+---------+
# | subject | hadm_id | stay_id | itemid | value   | valuenu | valueuo | label   | abbrevi | unitnam |
# | _id     | ---     | ---     | ---    | ---     | m       | m       | ---     | ation   | e       |
# | ---     | i64     | i64     | i64    | str     | ---     | ---     | str     | ---     | ---     |
# | i64     |         |         |        |         | f64     | str     |         | str     | str     |
# +==================================================================================================+
# | 1003797 | 2761792 | 3906157 | 223948 | Strong/ | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Strong/ | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Strong/ | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Easily  | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Easily  | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Easily  | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Easily  | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Easily  | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Easily  | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Weak    | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Strong/ | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Strong/ | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Strong/ | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Strong/ | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1003797 | 2761792 | 3906157 | 223948 | Strong/ | null    | null    | Radial  | Radial  | null    |
# | 5       | 9       | 1       |        | Palpabl |         |         | Pulse L | Pulse L |         |
# |         |         |         |        | e       |         |         |         |         |         |
# |---------+---------+---------+--------+---------+---------+---------+---------+---------+---------|
# | 1
# %%
# Now since everything is filtered, these are our lists
print(clean_codes)
print(important_labels)
# Out:
# {'Blood Pressure': {225309: ('ART BP Systolic', 4152194, 'Systolic blood pressure'), 220179: ('Non Invasive Blood Pressure Systolic', 4152194, 'Systolic blood pressure'), 220050: ('Arterial Blood Pressure Systolic', 4152194, 'Systolic blood pressure')}, 'Temperature': {223762: ('Temperature Celsius', 36716470, 'Temperature')}, 'BUN': {225624: ('BUN', 4017361, 'Blood urea nitrogen measurement')}, 'pH': {223830: ('PH (Arterial)', 4097822, 'pH measurement, arterial')}, 'Sodium': {220645: ('Sodium (serum)', 4097430, 'Sodium measurement'), 226534: ('Sodium (whole blood)', 4097430, 'Sodium measurement')}, 'Glucose': {226537: ('Glucose (whole blood)', 4149519, 'Glucose measurement'), 220621: ('Glucose (serum)', 4149519, 'Glucose measurement')}, 'Hematocrit': {226540: ('Hematocrit (whole blood - calc)', 4151358, 'Hematocrit determination'), 220545: ('Hematocrit (serum)', 4151358, 'Hematocrit determination')}}
# {('anchor_age', 4265453, 'Age'), ('admission_location', 45883663, 'Nursing Home'), ('gender', 4135376, 'Gender')}

# %%
# pivoted table (did it manually)
data_labels = [
    ('gender', 'anchor_age', 'admission_location'),
    (4135376, 4265453, 45883663),
    ('Gender', 'Age', 'Nursing Home')
]

# Create the Polars DataFrame
df_labels = pl.DataFrame(data_labels, schema=[("label", pl.Utf8), ("concept_id", pl.Int64), ("concept_name", pl.Utf8)], strict=False)

df_labels
# Out:
# shape: (3, 3)
# +--------------------+------------+--------------+
# | label              | concept_id | concept_name |
# | ---                | ---        | ---          |
# | str                | i64        | str          |
# +================================================+
# | gender             | 4135376    | Gender       |
# |--------------------+------------+--------------|
# | anchor_age         | 4265453    | Age          |
# |--------------------+------------+--------------|
# | admission_location | 45883663   | Nursing Home |
# +--------------------+------------+--------------+

# %%
data_one = [(k, int(v[1]), v[2]) for group in clean_codes.values() for k, v in group.items()]
df_one = pl.DataFrame(data_one, schema=[("itemid", pl.Int64), ("new_concept_id", pl.Int64), ("new_concept_name", pl.Utf8)])

df_one
# Out:
# /Users/jonas/Programming/Anaconda/anacondaMac/anaconda3/envs/meddata/lib/python3.10/functools.py:889: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return dispatch(args[0].__class__)(*args, **kw)
# shape: (12, 3)
# +--------+----------------+-----------------------------------+
# | itemid | new_concept_id | new_concept_name                  |
# | ---    | ---            | ---                               |
# | i64    | i64            | str                               |
# +=============================================================+
# | 225309 | 4152194        | Systolic blood pressure           |
# |--------+----------------+-----------------------------------|
# | 220179 | 4152194        | Systolic blood pressure           |
# |--------+----------------+-----------------------------------|
# | 220050 | 4152194        | Systolic blood pressure           |
# |--------+----------------+-----------------------------------|
# | 223762 | 36716470       | Temperature                       |
# |--------+----------------+-----------------------------------|
# | 225624 | 4017361        | Blood urea nitrogen measuremen... |
# |--------+----------------+-----------------------------------|
# | 223830 | 4097822        | pH measurement, arterial          |
# |--------+----------------+-----------------------------------|
# | 220645 | 4097430        | Sodium measurement                |
# |--------+----------------+-----------------------------------|
# | 226534 | 4097430        | Sodium measurement                |
# |--------+----------------+-----------------------------------|
# | 226537 | 4149519        | Glucose measurement               |
# |--------+----------------+-----------------------------------|
# | 220621 | 4149519        | Glucose measurement               |
# |--------+----------------+-----------------------------------|
# | 226540 | 4151358        | Hematocrit determination          |
# |--------+----------------+-----------------------------------|
# | 220545 | 4151358        | Hematocrit determination          |
# +--------+----------------+-----------------------------------+

# %%
# now using left joins to add the new colums to our dataframe
joined_df = df.join(df_labels, on="label", how="left")


columns = joined_df.columns
print(columns)

# join the second table
joined_df = joined_df.join(df_one, on="itemid", how="left")

columns = joined_df.columns
print(columns)

# merge the columns 
joined_df = joined_df.with_columns([
    pl.when(pl.col("concept_id").is_null())
    .then(pl.col("new_concept_id"))
    .otherwise(pl.col("concept_id"))
    .alias("concept_id"),
    pl.when(pl.col("concept_name").is_null())
    .then(pl.col("new_concept_name"))
    .otherwise(pl.col("concept_name"))
    .alias("concept_name")
])

# Drop the temporary columns if they are no longer needed
joined_df = joined_df.drop(["new_concept_id", "new_concept_name"])

# Filter out rows where concept_id is null - these are the values that we had to filter out since they arent needed for our calculation
result = joined_df.filter(~pl.col("concept_id").is_null())
result
# Out:
# ['subject_id', 'hadm_id', 'stay_id', 'itemid', 'value', 'valuenum', 'valueuom', 'label', 'abbreviation', 'unitname', 'concept_id', 'concept_name']
# ['subject_id', 'hadm_id', 'stay_id', 'itemid', 'value', 'valuenum', 'valueuom', 'label', 'abbreviation', 'unitname', 'concept_id', 'concept_name', 'new_concept_id', 'new_concept_name']
# shape: (2_549, 12)
# +--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | subjec | hadm_i | stay_i | itemi | value | value | value | label | abbre | unitn | conce | conce |
# | t_id   | d      | d      | d     | ---   | num   | uom   | ---   | viati | ame   | pt_id | pt_na |
# | ---    | ---    | ---    | ---   | str   | ---   | ---   | str   | on    | ---   | ---   | me    |
# | i64    | i64    | i64    | i64   |       | f64   | str   |       | ---   | str   | i64   | ---   |
# |        |        |        |       |       |       |       |       | str   |       |       | str   |
# +==================================================================================================+
# | 100379 | 276179 | 390615 | 22005 | 105   | 105.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 114   | 114.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 122   | 122.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 107   | 107.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 109   | 109.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 104   | 104.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 118   | 118.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 108   | 108.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 124   | 124.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 106   | 106.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 130   | 130.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 126   | 126.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 111   | 111.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 96    | 96.0  | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 94    | 94.0  | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22376 | 39.7  | 39.7  | °C    | Tempe | Tempe | °C    | 36716 | Tempe |
# | 75     | 29     | 71     | 2     |       |       |       | ratur | ratur |       | 470   | ratur |
# |        |        |        |       |       |       |       | e Cel | e C   |       |       | e     |
# |        |        |        |       |       |       |       | sius  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 99    | 99.0  | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22376 | 40.4  | 40.4  | °C    | Tempe | Tempe | °C    | 36716 | Tempe |
# | 75     | 29     | 71     | 2     |       |       |       | ratur | ratur |       | 470   | ratur |
# |        |        |        |       |       |       |       | e Cel | e C   |       |       | e     |
# |        |        |        |       |       |       |       | sius  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 106   | 106.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 22005 | 117   | 117.0 | mmHg  | Arter | ABPs  | mmHg  | 41521 | Systo |
# | 75     | 29     | 71     | 0     |       |       |       | ial   |       |       | 94    | lic   |
# |        |        |        |       |       |       |       | Blood |       |       |       | blood |
# |        |        |        |       |       |       |       | Press |       |       |       | press |
# |        |        |        |       |       |       |       | ure   |       |       |       | ure   |
# |        |        |        |       |       |       |       | systo |       |       |       |       |
# |        |        |        |       |       |       |       | l...  |       |       |       |       |
# |--------+--------+--------+-------+-------+-------+-------+-------+-------+-------+-------+-------|
# | 100379 | 276179 | 390615 | 